# %%
import pandas as pd

df = pd.read_parquet('../rust-ingest/pcap_samples/ny4-small-10m_parsed.parquet')
df.shape
# Out:
# (10000000, 4)

# %%
df.head()
# Out:
#    packet_index  udp_payload_len  block_size  messages_in_block
# 0             0              108         108                  3
# 1             1               50          50                  1
# 2             2              166         166                  5
# 3             3               50          50                  1
# 4             4              108         108                  3

# %%
df.tail()
# Out:
#          packet_index  udp_payload_len  block_size  messages_in_block
# 9999995       9999995               50          50                  1
# 9999996       9999996               50          50                  1
# 9999997       9999997               50          50                  1
# 9999998       9999998               50          50                  1
# 9999999       9999999              138         138                  4

# %%
import pandas as pd

df = pd.read_parquet('../rust-ingest/pcap_samples/ny4-small-10k_trades.parquet')
df.shape
# Out:
# (14440, 19)

# %%
df.head(20)
# Out:
#     packet_index  block_sequence   block_timestamp_ns  message_index_in_block  \
# 0              0       355512323  1692714599999800576                       0
# 1              0       355512323  1692714599999800576                       1
# 2              0       355512323  1692714599999800576                       2
# 3              1       207634110  1692714599999804416                       0
# 4              2       263110673  1692714599999802624                       0
# 5              2       263110673  1692714599999802624                       1
# 6              2       263110673  1692714599999802624                       2
# 7              2       263110673  1692714599999802624                       3
# 8              2       263110673  1692714599999802624                       4
# 9              3       263110678  1692714599999807744                       0
# 10             4       207634111  1692714599999810816                       0
# ...

# %%
df.tail()
# Out:
#        packet_index  block_sequence   block_timestamp_ns  \
# 14435          9997       263119048  1692714600031779072
# 14436          9998       207639644  1692714600031791104
# 14437          9998       207639644  1692714600031791104
# 14438          9998       207639644  1692714600031791104
# 14439          9999       355521879  1692714600031791872
#
#        message_index_in_block participant category type_code indicator  \
# 14435                       0           Q        q                   A
# 14436                       0           H        q                   A
# 14437                       1           Q        q                   A
# 14438                       2           I        q                   A
# 14439                       0           H        q                   A
#
#       symbol_root           osi_symbol     bid     ask  bid_size  ask_size  \
# 14435         SPY  SPY 230828C00435000    6.62    6.67         6        70
# ...
